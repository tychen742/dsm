# %%
from datascience import *
import numpy as np
# %matplotlib inline

# %%
### q01
die = Table().with_column(
    'Face', np.arange(1, 7)
)
die
# Out:
# Face
# 1
# 2
# 3
# 4
# 5
# 6

# %%
### q02
die_bins = np.arange(0.5, 6.6, 1)
die.hist(bins = die_bins)

# %%
### q03
die.sample(10)[0]
# Out:
# array([4, 6, 1, 3, 3, 1, 6, 5, 5, 2])

# %%
faces = make_array()
# repetitions = 1000
def empirical_hist(repetitions):
    die.sample(repetitions).hist(bins = die_bins)

empirical_hist(1000)

# %%
### Jacob Meyers
def empirical_hist(n):
    sample = die.sample(n)
    sample.hist(bins = die_bins)
empirical_hist(1000)

# %%
### Joshua England

def empirical_hist(num):
    # rolls = die.sample(num)[0]
    rolls = die.sample(num)
    return rolls.hist(bins = die_bins)

empirical_hist(1000)

# %%
### Terrell Heredia
def empirical_hist(n):
    # die.with_column('Times Selected', die.sample(n))
    die.sample(n).hist('Face', bins = die_bins)

empirical_hist(1000)

# %%
### Avery Mitchell
def empirical_hist(sim:int):
    samples = die.sample(sim)
    samples.hist(bins= die_bins)

empirical_hist(1000)

# %%
### Connor Shorts
def empirical_hist(num_rolls):
    # die.hist(die.sample(num_rolls), bins = die_bins)
    # die.sample(num_rolls).hist( bins = die_bins)

    return die.sample(num_rolls)

empirical_hist(1000)
# Out:
# Face
# 2
# 6
# 4
# 3
# 1
# 5
# 6
# 3
# 1
# 6
# ... (990 rows omitted)

# %%
### Chris Holland
def empirical_hist(int):
    die_run = die.sample(int)
    die_run.hist(bins = die_bins)

empirical_hist(1000)
