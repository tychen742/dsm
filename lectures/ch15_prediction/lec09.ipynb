# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import warnings
# warnings.simplefilter(action='ignore',category=np.VisibleDeprecationWarning)

# %% [markdown]
# ## Lecture 09 ##

# %% [markdown]
# ## Prediction ##

# %%
families = Table.read_table('family_heights.csv')
families
# Out:
# family | father | mother | midparentHeight | children | childNum | sex    | childHeight
# 1      | 78.5   | 67     | 75.43           | 4        | 1        | male   | 73.2
# 1      | 78.5   | 67     | 75.43           | 4        | 2        | female | 69.2
# 1      | 78.5   | 67     | 75.43           | 4        | 3        | female | 69
# 1      | 78.5   | 67     | 75.43           | 4        | 4        | female | 69
# 2      | 75.5   | 66.5   | 73.66           | 4        | 1        | male   | 73.5
# 2      | 75.5   | 66.5   | 73.66           | 4        | 2        | male   | 72.5
# 2      | 75.5   | 66.5   | 73.66           | 4        | 3        | female | 65.5
# 2      | 75.5   | 66.5   | 73.66           | 4        | 4        | female | 65.5
# 3      | 75     | 64     | 72.06           | 2        | 1        | male   | 71
# 3      | 75     | 64     | 72.06           | 2        | 2        | female | 68
# ... (924 rows omitted)

# %%
parent_avgs = (families.column('father') + families.column('mother'))/2

# %%
heights = Table().with_columns(
    'Parent Average', parent_avgs,
    # 'Child', families.column('child'),
    'Child', families.column('childHeight'),
    'Sex', families.column('sex')
)
heights
# Out:
# Parent Average | Child | Sex
# 72.75          | 73.2  | male
# 72.75          | 69.2  | female
# 72.75          | 69    | female
# 72.75          | 69    | female
# 71             | 73.5  | male
# 71             | 72.5  | male
# 71             | 65.5  | female
# 71             | 65.5  | female
# 69.5           | 71    | male
# 69.5           | 68    | female
# ... (924 rows omitted)

# %%
heights.scatter('Parent Average', 'Child')

# %%
heights.scatter('Parent Average', 'Child')
plots.plot([67.5, 67.5], [50, 85], color='red', lw=2)
plots.plot([68.5, 68.5], [50, 85], color='red', lw=2);

# %%
nearby = heights.where('Parent Average', are.between(67.5, 68.5))
nearby_mean = np.average(nearby.column('Child'))
nearby_mean
# Out:
# 67.620000000000005

# %%
heights.scatter('Parent Average', 'Child')
plots.plot([67.5, 67.5], [50, 85], color='red', lw=2)
plots.plot([68.5, 68.5], [50, 85], color='red', lw=2)
plots.scatter(68, nearby_mean, color='red', s=50);

# %%
def predict(h):
    nearby = heights.where('Parent Average', are.between(h - 1/2, h + 1/2))
    return np.average(nearby.column('Child'))

# %%
predict(68)
# Out:
# 67.620000000000005

# %%
predict(70)
# Out:
# 68.561904761904756

# %%
predict(73)
# Out:
# 70.099999999999994

# %%
predicted_heights = heights.apply(predict, 'Parent Average')

# %%
heights = heights.with_column('Prediction', predicted_heights)

# %%
heights.select('Parent Average', 'Child', 'Prediction').scatter('Parent Average')

# %% [markdown]
# ## Prediction Accuracy ##

# %%
def difference(x, y):
    return x - y

# %%
pred_errs = heights.apply(difference, 'Prediction', 'Child')
heights = heights.with_column('errors',pred_errs)
heights
# Out:
# Parent Average | Child | Sex    | Prediction | errors
# 72.75          | 73.2  | male   | 70.1       | -3.1
# 72.75          | 69.2  | female | 70.1       | 0.9
# 72.75          | 69    | female | 70.1       | 1.1
# 72.75          | 69    | female | 70.1       | 1.1
# 71             | 73.5  | male   | 70.4158    | -3.08421
# 71             | 72.5  | male   | 70.4158    | -2.08421
# 71             | 65.5  | female | 70.4158    | 4.91579
# 71             | 65.5  | female | 70.4158    | 4.91579
# 69.5           | 71    | male   | 68.5025    | -2.4975
# 69.5           | 68    | female | 68.5025    | 0.5025
# ... (924 rows omitted)

# %%
heights.hist('errors')

# %%
heights.hist('errors', group='Sex')

# %% [markdown]
# # Discussion Question

# %%
def predict_smarter(h, s):
    nearby = heights.where('Parent Average', are.between(h - 1/2, h + 1/2))
    nearby_same_sex = nearby.where('Sex', s)
    return np.average(nearby_same_sex.column('Child'))

# %%
predict_smarter(68, 'female')
# Out:
# 64.983516483516482

# %%
predict_smarter(68, 'male')
# Out:
# 70.172340425531914

# %%
smarter_predicted_heights = heights.apply(predict_smarter, 'Parent Average', 'Sex')
heights = heights.with_column('Smarter Prediction', smarter_predicted_heights)

# %%
smarter_pred_errs = heights.apply(difference, 'Child', 'Smarter Prediction')
heights = heights.with_column('Smarter Errors', smarter_pred_errs)

# %%
heights.hist('Smarter Errors', group='Sex')

# %% [markdown]
# ## Grouping by One Column ##

# %%
cones = Table.read_table('cones.csv').drop('Color')
cones
# Out:
# Flavor     | Price
# strawberry | 3.55
# chocolate  | 4.75
# chocolate  | 5.25
# strawberry | 5.25
# chocolate  | 5.25
# bubblegum  | 4.75

# %%
cones.group('Flavor')
# Out:
# Flavor     | count
# bubblegum  | 1
# chocolate  | 3
# strawberry | 2

# %%
cones.group('Flavor', np.average)
# Out:
# Flavor     | Price average
# bubblegum  | 4.75
# chocolate  | 5.08333
# strawberry | 4.4

# %%
cones.group('Flavor', np.min)
# Out:
# Flavor     | Price min
# bubblegum  | 4.75
# chocolate  | 4.75
# strawberry | 3.55

# %% [markdown]
# ## Grouping By One Column: Welcome Survey ##

# %%
survey = Table.read_table('welcome_survey_fa22.csv')
survey.show(3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 survey = Table.read_table('welcome_survey_fa22.csv')
#       2 survey.show(3)
#
# File ~/workspace/introdsm/.venv/lib/python3.12/site-packages/datascience/tables.py:163, in Table.read_table(cls, filepath_or_buffer, *args, **vargs)
#     161 except AttributeError:
#     162     pass
# --> 163 df = pandas.read_csv(filepath_or_buffer, *args, **vargs)
#     164 return cls.from_df(df)
#
# File ~/workspace/introdsm/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/workspace/introdsm/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/workspace/introdsm/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/workspace/introdsm/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/workspace/introdsm/.venv/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'welcome_survey_fa22.csv'

# %%
survey.hist('Extroversion')

# %%
by_extra = survey.group('Extroversion', np.average)
by_extra

# %%
by_extra.plot('Extroversion', 'Number of textees average')

# %%
survey.group("Year")

# %%
(survey
 .select("Year", "Hours of sleep")
 .group(0, np.average)
 .take(1, 4, 5, 2))

# %% [markdown]
# ## Lists

# %%
[1, 5, 'hello', 5.0]

# %%
[1, 5, 'hello', 5.0, make_array(1,2,3)]

# %% [markdown]
# ## Grouping by Two Columns ##

# %% [markdown]
# ![Do right-handed people tend to sleep on their left side and left-handed people sleep on their right?](handed.png)

# %%
survey.group(['Handedness', 'Sleep position']).show()
